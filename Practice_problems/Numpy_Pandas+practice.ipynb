# %% [markdown]
# 1. Student Marks Analyzer
# You are helping a teacher check exam results.
# Create a NumPy array with 10 random integers between 0 and 100 (student scores).
# Find:
# - the highest score
# - the lowest score
# - the average score
#
# Hint: use np.random.randint(), arr.max(), arr.min(), arr.mean()

# %%
import numpy as np
result = np.random.randint(0, 100, 10)
mx = result.max()
print(mx)
mn = result.min()
print(mn)
avrg = result.mean()
print(avrg)
print(result)
# Out:
# 99
# 14
# 63.0
# [86 88 49 76 62 14 57 99 35 64]
